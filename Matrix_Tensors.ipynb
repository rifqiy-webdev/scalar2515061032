# %%
import numpy as np

# %%
#1. buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[1,2,3],[7,8,9]])
x
# Out:
# array([[1, 2, 3],
#        [7, 8, 9]])

# %%
#tampilkan ukuran dari matrix X
x.shape
# Out:
# (2, 3)

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X
x[:,0]
# Out:
# array([1, 7])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
x[1:2]
# Out:
# array([[7, 8, 9]])

# %%
#2. ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
#buat matrix X berukuran 2x3 menggunakan pytoch
x_pt = torch.tensor([[1,2,3],[7,8,9]])
x_pt
# Out:
# tensor([[1, 2, 3],
#         [7, 8, 9]])

# %%
#tampilkan ukuran dari matrix X
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X
x_pt[:,0]
# Out:
# tensor([1, 7])

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
x_pt[1:2]
# Out:
# tensor([[7, 8, 9]])

# %%
#ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
#buat matrix X berukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[1,2,3],[7,8,9]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[1, 2, 3],
#        [7, 8, 9]], dtype=int32)>

# %%
#tampilkan ukuran dari matrix X
x_tf.shape
# Out:
# TensorShape([2, 3])

# %%
#tampilkan seluruh elemen dari kolom pertama dari matrix X
x_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([1, 7], dtype=int32)>

# %%
#tampilkan seluruh elemen dari baris kedua dari matrix X
x_tf[1:2]
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[7, 8, 9]], dtype=int32)>
