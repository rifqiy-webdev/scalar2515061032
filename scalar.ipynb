# %%
#1.buat variabel skalar x dan simpan suatu nilai skalar
x = 32

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y=23

# %%
#tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 55

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 32.5

# %%
#jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 55.5

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
#2.lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(32)

# %%
# tampilkan tipe data x
dtype_tf = x_tf
dtype_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=32>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(23.0)

# %%
# tampilkan tipe data x
dtype = y_tf
dtype
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=23>

# %%
#jumlahkan x+y
tf_sum = tf.add(x_tf, y_tf)
tf_sum

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = tf.Variable(32.5)

# %%
#jumlahkan x_float dengan y
float_sum = tf.add(x_float, y_tf)
float_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=55.5>

# %%
#tampilkan tipe data dari x_float
dtype = x_float
dtype
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=32.5>

# %%
#3.lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(32)

# %%
# tampilkan tipe data x
type(x_pt)
# Out:
# torch.Tensor

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(23.0)

# %%
# tampilkan tipe data x
type(y_pt)
# Out:
# torch.Tensor

# %%
#jumlahkan x+y
pt_sum = torch.add(x_pt, y_pt)
pt_sum
# Out:
# tensor(55)

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = torch.tensor(32.5)

# %%
#jumlahkan x_float dengan y
float_sum = torch.add(x_float, y_pt)
float_sum
# Out:
# tensor(55.5000)

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# torch.Tensor
